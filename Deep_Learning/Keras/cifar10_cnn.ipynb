# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 58s 0us/step

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=3, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 32, 32, 16)        448
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 32)        4640
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 64)          18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 541,094
# Trainable params: 541,094
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=20,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/20
#  - 14s - loss: 1.5692 - acc: 0.4299 - val_loss: 1.3532 - val_acc: 0.5236
#
# Epoch 00001: val_loss improved from inf to 1.35321, saving model to model.weights.best.hdf5
# Epoch 2/20
#  - 14s - loss: 1.2272 - acc: 0.5592 - val_loss: 1.1176 - val_acc: 0.5956
#
# Epoch 00002: val_loss improved from 1.35321 to 1.11756, saving model to model.weights.best.hdf5
# Epoch 3/20
#  - 14s - loss: 1.0841 - acc: 0.6148 - val_loss: 1.3204 - val_acc: 0.5574
#
# Epoch 00003: val_loss did not improve from 1.11756
# Epoch 4/20
#  - 14s - loss: 0.9848 - acc: 0.6534 - val_loss: 0.8883 - val_acc: 0.6884
#
# Epoch 00004: val_loss improved from 1.11756 to 0.88834, saving model to model.weights.best.hdf5
# Epoch 5/20
#  - 14s - loss: 0.9128 - acc: 0.6764 - val_loss: 0.8512 - val_acc: 0.7064
#
# Epoch 00005: val_loss improved from 0.88834 to 0.85123, saving model to model.weights.best.hdf5
# Epoch 6/20
#  - 14s - loss: 0.8595 - acc: 0.6971 - val_loss: 0.7903 - val_acc: 0.7252
#
# Epoch 00006: val_loss improved from 0.85123 to 0.79035, saving model to model.weights.best.hdf5
# Epoch 7/20
#  - 14s - loss: 0.8108 - acc: 0.7145 - val_loss: 0.7822 - val_acc: 0.7302
#
# Epoch 00007: val_loss improved from 0.79035 to 0.78224, saving model to model.weights.best.hdf5
# Epoch 8/20
#  - 14s - loss: 0.7709 - acc: 0.7251 - val_loss: 0.7647 - val_acc: 0.7352
#
# Epoch 00008: val_loss improved from 0.78224 to 0.76468, saving model to model.weights.best.hdf5
# Epoch 9/20
#  - 14s - loss: 0.7450 - acc: 0.7388 - val_loss: 0.7453 - val_acc: 0.7416
#
# Epoch 00009: val_loss improved from 0.76468 to 0.74530, saving model to model.weights.best.hdf5
# Epoch 10/20
#  - 14s - loss: 0.7129 - acc: 0.7463 - val_loss: 0.7279 - val_acc: 0.7474
#
# Epoch 00010: val_loss improved from 0.74530 to 0.72788, saving model to model.weights.best.hdf5
# Epoch 11/20
#  - 14s - loss: 0.6895 - acc: 0.7563 - val_loss: 0.7444 - val_acc: 0.7406
#
# Epoch 00011: val_loss did not improve from 0.72788
# Epoch 12/20
#  - 14s - loss: 0.6665 - acc: 0.7662 - val_loss: 0.7485 - val_acc: 0.7408
#
# Epoch 00012: val_loss did not improve from 0.72788
# Epoch 13/20
#  - 14s - loss: 0.6386 - acc: 0.7731 - val_loss: 0.7132 - val_acc: 0.7548
#
# Epoch 00013: val_loss improved from 0.72788 to 0.71318, saving model to model.weights.best.hdf5
# Epoch 14/20
#  - 14s - loss: 0.6268 - acc: 0.7787 - val_loss: 0.7094 - val_acc: 0.7534
#
# Epoch 00014: val_loss improved from 0.71318 to 0.70943, saving model to model.weights.best.hdf5
# Epoch 15/20
#  - 14s - loss: 0.6084 - acc: 0.7830 - val_loss: 0.7341 - val_acc: 0.7506
#
# Epoch 00015: val_loss did not improve from 0.70943
# Epoch 16/20
#  - 14s - loss: 0.5918 - acc: 0.7887 - val_loss: 0.7102 - val_acc: 0.7588
#
# Epoch 00016: val_loss did not improve from 0.70943
# Epoch 17/20
#  - 14s - loss: 0.5755 - acc: 0.7944 - val_loss: 0.7488 - val_acc: 0.7418
#
# Epoch 00017: val_loss did not improve from 0.70943
# Epoch 18/20
#  - 14s - loss: 0.5660 - acc: 0.7988 - val_loss: 0.7089 - val_acc: 0.7610
#
# Epoch 00018: val_loss improved from 0.70943 to 0.70886, saving model to model.weights.best.hdf5
# Epoch 19/20
#  - 14s - loss: 0.5508 - acc: 0.8040 - val_loss: 0.6962 - val_acc: 0.7628
#
# Epoch 00019: val_loss improved from 0.70886 to 0.69618, saving model to model.weights.best.hdf5
# Epoch 20/20
#  - 14s - loss: 0.5387 - acc: 0.8090 - val_loss: 0.7272 - val_acc: 0.7582
#
# Epoch 00020: val_loss did not improve from 0.69618

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7522

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
